# %%
import requests
# from selenium import webdriver
# from selenium.webdriver.common.keys import Keys
# from webdriver_manager.chrome import ChromeDriverManager
# from selenium.webdriver.common.by import By


# import time
# from bs4 import BeautifulSoup

import pandas as pd
import urllib.request

# %%
headers = {
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.9,ar-EG;q=0.8,ar;q=0.7,tr-TR;q=0.6,tr;q=0.5',
    'Connection': 'keep-alive',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'Origin': 'https://www.dataprivacyframework.gov',
    'Referer': 'https://www.dataprivacyframework.gov/s/participant-search',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36',
    'X-SFDC-LDS-Endpoints': 'ApexActionController.execute:dpfParticipationService.getParticipants',
    'X-SFDC-Page-Scope-Id': '274ad222-c5ce-4b8c-a8f9-bda7194ea411',
    'X-SFDC-Request-Id': '23210000000f732bf4',
    'sec-ch-ua': '"Chromium";v="118", "Google Chrome";v="118", "Not=A?Brand";v="99"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
}

params = {
    'r': '4',
    'aura.ApexAction.execute': '1',
}

data = {
    'message': '{"actions":[{"id":"248;a","descriptor":"aura://ApexActionController/ACTION$execute","callingDescriptor":"UNKNOWN","params":{"namespace":"","classname":"dpfParticipationService","method":"getParticipants","params":{"status":"Inactive","searchTerm":"","selectedProgram":"","selectedDataType":"","serviceProvider":"","startsWith":""},"cacheable":false,"isContinuation":false}}]}',
    'aura.context': '{"mode":"PROD","fwuid":"MDM0c01pMVUtd244bVVLc2VRYzQ2UWRkdk8xRWxIam5GeGw0LU1mRHRYQ3cyNDYuMTUuMy0zLjAuNA","app":"siteforce:communityApp","loaded":{"APPLICATION@markup://siteforce:communityApp":"Q0rLNWd4PlXUU9-_ILiuNg","COMPONENT@markup://instrumentation:o11ySecondaryLoader":"Cpu-nBuFEwwbtqFxYd7Qhw"},"dn":[],"globals":{},"uad":false}',
    'aura.pageURI': '/s/participant-search',
    'aura.token': 'null',
}

response = requests.post(
    'https://www.dataprivacyframework.gov/s/sfsites/aura',
    params=params,
    headers=headers,
    data=data,
)

# %%
data_for_id = response.json()

# %%
id_list = []
for i in range(3766):
    item_dict = {}
    id_ = data_for_id['actions'][0]['returnValue']['returnValue'][i]['id']
    id_list.append(id_)

# %%
len(id_list)
# Out:
# 3766

# %%
data_list = []

for id_ in (id_list):
  
    print('id ',id_, ' is processing...')

    headers = {
        'Accept': '*/*',
        'Accept-Language': 'en-US,en;q=0.9,ar-EG;q=0.8,ar;q=0.7,tr-TR;q=0.6,tr;q=0.5',
        'Connection': 'keep-alive',
        'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
        'Origin': 'https://www.dataprivacyframework.gov',
        'Referer': f'https://www.dataprivacyframework.gov/s/participant-search/participant-detail?id={id_}&status=Inactive',
        'Sec-Fetch-Dest': 'empty',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Site': 'same-origin',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36',
        'X-SFDC-LDS-Endpoints': 'ApexActionController.execute:dpfParticipationProfileController.getParticipant',
        'X-SFDC-Page-Cache': '30904dbea2ec2925',
        'X-SFDC-Page-Scope-Id': '1ab6d816-ee0f-450a-b499-8aa4595854c5',
        'X-SFDC-Request-Id': '463430000064cd91ed',
        'sec-ch-ua': '"Chromium";v="118", "Google Chrome";v="118", "Not=A?Brand";v="99"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        }

    params = {
            'r': '1',
            'aura.ApexAction.execute': '1',
        }

    data = {
        
        'message':'{"actions":[{"id":"193;a","descriptor":"aura://ApexActionController/ACTION$execute","callingDescriptor":"UNKNOWN","params":{"namespace":"","classname":"dpfParticipationProfileController","method":"getParticipant","params":{"status":"Inactive","participationId":"a2zt0000000PFClAAO"},"cacheable":false,"isContinuation":false}}]}',
        'aura.context': '{"mode":"PROD","fwuid":"MDM0c01pMVUtd244bVVLc2VRYzQ2UWRkdk8xRWxIam5GeGw0LU1mRHRYQ3cyNDYuMTUuMy0zLjAuNA","app":"siteforce:communityApp","loaded":{"APPLICATION@markup://siteforce:communityApp":"Q0rLNWd4PlXUU9-_ILiuNg","COMPONENT@markup://instrumentation:o11ySecondaryLoader":"Cpu-nBuFEwwbtqFxYd7Qhw"},"dn":[],"globals":{},"uad":false}',
        'aura.pageURI': f'/s/participant-search/participant-detail?id={id_}&status=Inactive',
        'aura.token': 'null',
    }
    
    part1 = data['message'].split('"participationId":"')[0]
    part2 = data['message'].split('"participationId":"')[1].split('"}')[1]
    data['message'] = part1 + '"participationId":"' + str(id_) +'"}' +part2
    
    #print(data['message'])
    
    response = requests.post(
        'https://www.dataprivacyframework.gov/s/sfsites/aura',
        params=params,
        headers=headers,
        data=data,
    )
    
    details = response.json()
    data_dict = {}

    try:
        root_data = details['actions'][0]['returnValue']['returnValue']
    except:
        pass
    try:
        data_dict['Company'] = root_data['name']
    except:
        pass
    try:
        data_dict['Name'] = root_data['appContact']['First_Name__c'] + ' ' + root_data['appContact']['Last_Name__c']
    except:
        pass
    try:
        data_dict['Title'] = root_data['appContact']['Title__c']
    except:
        pass
    try:
        data_dict['Email'] = root_data['appContact']['Email__c']
    except:
        pass
    try:
        data_dict['Address1'] = root_data['legalName']
    except:
        pass
    try:
        orgAddress = root_data['orgAddress']
    except:
        pass
    try:
        data_dict['Address2'] = orgAddress['streetAddress']
    except:
        pass
    try:
        data_dict['Address3'] = orgAddress['city'] + ', ' + orgAddress['state'] + ' ' + orgAddress['zipCode']
    except:
        pass
    try:
        data_dict['Phone'] = root_data['appContact']['Phone__c']
    except:
        pass
    data_list.append(data_dict)
    print(len(data_list))
#    print(data_dict)
#print(data_list)
# Out:
# id  a2zt0000000PFClAAO  is processing...
# 1
# id  a2zt0000000PJNjAAO  is processing...
# 2
# id  a2zt00000008WQ8AAM  is processing...
# 3
# id  a2zt0000000GpEPAA0  is processing...
# 4
# id  a2zt00000008hXZAAY  is processing...
# 5
# id  a2zt00000008VqiAAE  is processing...
# 6
# id  a2zt00000008UzDAAU  is processing...
# 7
# id  a2zt0000000TOKjAAO  is processing...
# 8
# id  a2zt0000000eF01AAE  is processing...
# 9
# id  a2zt0000000PFpOAAW  is processing...
# 10
# id  a2zt0000000TXFlAAO  is processing...
# 11
# id  a2zt0000000CooLAAS  is processing...
# 12
# id  a2zt0000000bltqAAA  is processing...
# 13
# id  a2zt0000000TT1zAAG  is processing...
# 14
# id  a2zt0000000CjpBAAS  is processing...
# 15
# id  a2zt00000008VIAAA2  is processing...
# 16
# id  a2zt0000000TXjoAAG  is processing...
# 17
# id  a2zt000000000bgAAA  is processing...
# 18
# id  a2zt0000000TNysAAG  is processing...
# 19
# id  a2zt0000000L1P6AAK  is processing...
# 20
# id  a2zt0000000GosvAAC  is processing...
# 21
# ...

# %%
df = pd.DataFrame(data_list)

# %%
df
# Out:
#                        Company             Name                      Title  \
# 0                     1010data  Steven Dimirsky    Chief Corporate Counsel
# 1                  11trees LLC    Andrew McCann              Founder & CEO
# 2     15 Seconds of Fame, Inc.   Ruslan Sabitov   Chief Technology Officer
# 3                       15Five     Nazar Ivaniv                        NaN
# 4               20|20 Research     Luke Pickard                        NaN
# ...                        ...              ...                        ...
# 3761                      Zoom     Donna Hughes            Privacy Analyst
# 3762           Zoomforth, Inc.     WENDIE MICHE                        CEO
# 3763    Zoot Enterprises, Inc.    Leesa Gregory  Associate General Counsel
# 3764                    Zorroa   Danny Tiesling            Privacy Contact
# 3765                    zPaper       Tom Malone            Project Manager
#
# ...

# %%
df.to_excel('Data_upwork_attempt1.xlsx', index=False)
